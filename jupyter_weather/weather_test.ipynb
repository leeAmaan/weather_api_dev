# %%
import json
import pandas as pd
import datetime
from datetime import timedelta 
from urllib.request import urlopen

# %%
service_key = 'nQOFCISJ3ToYr2BuYqeag3Ds0%2BQ5TnGHX4dpxs0YfNhRqWE0cqU1Fz%2B7ARZQI%2BdpNRvzJKJXX2V3q%2BjLu%2BCdEQ%3D%3D'
numOfRows = '500'
pageNo = '1'
dataCd = 'ASOS'
dateCd = 'HR'
stnlds = '108'
endDt = '20221120'
endHh = '05'
startHh = '06'
startDt = '20220401'
dataType = 'json'

# %%
api_url = 'http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList?serviceKey={}&numOfRows={}&pageNo={}&dataCd={}&dateCd={}&stnIds={}&endDt={}&endHh={}&startHh={}&startDt={}&dataType={}'.format(service_key, numOfRows, pageNo, dataCd, dateCd, stnlds, endDt, endHh, startHh, startDt, dataType)
response = urlopen(api_url)
json_data = json.loads(response.read().decode('utf8'))

# %%
json_data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'tm': '2022-04-01 06:00',
#       'rnum': '1',
#       'stnId': '108',
#       'stnNm': '서울',
#       'ta': '4.7',
#       'taQcflg': '',
#       'rn': '',
#       'rnQcflg': '',
#       'ws': '2.4',
#       'wsQcflg': '',
#       'wd': '50',
#       'wdQcflg': '',
#       'hm': '77',
#       'hmQcflg': '',
#       'pv': '6.6',
#       'td': '1.0',
#       'pa': '1018.5',
#       'paQcflg': '',
#       'ps': '1029.2',
#       'psQcflg': '',
#       'ss': '',
#       'ssQcflg': '9',
#       'icsr': '',
#       'dsnw': '',
#       'hr3Fhsc': '',
#       'dc10Tca': '1',
#       'dc10LmcsCa': '0',
#       'clfmAbbrCd': 'Ci',
#       'lcsCh': '',
#       'vs': '2000',
#       'gndSttCd': '',
#       'dmstMtphNo': '',
#       'ts': '3.5',
#       'tsQcflg': '',
#       'm005Te': '8.7',
#       'm01Te': '8.7',
#       'm02Te': '9.4',
# ...

# %%
a = json_data['response']['body']['items']['item']
df = pd.DataFrame(a)

# %%
df.columns
# Out:
# Index(['tm', 'rnum', 'stnId', 'stnNm', 'ta', 'taQcflg', 'rn', 'rnQcflg', 'ws',
#        'wsQcflg', 'wd', 'wdQcflg', 'hm', 'hmQcflg', 'pv', 'td', 'pa',
#        'paQcflg', 'ps', 'psQcflg', 'ss', 'ssQcflg', 'icsr', 'dsnw', 'hr3Fhsc',
#        'dc10Tca', 'dc10LmcsCa', 'clfmAbbrCd', 'lcsCh', 'vs', 'gndSttCd',
#        'dmstMtphNo', 'ts', 'tsQcflg', 'm005Te', 'm01Te', 'm02Te', 'm03Te'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                  tm rnum stnId stnNm    ta taQcflg rn rnQcflg   ws wsQcflg  \
# 0  2022-04-01 06:00    1   108    서울   4.7                     2.4
# 1  2022-04-01 07:00    2   108    서울   4.7                     1.7
# 2  2022-04-01 08:00    3   108    서울   6.5                     2.6
# 3  2022-04-01 09:00    4   108    서울   8.5                     2.7
# 4  2022-04-01 10:00    5   108    서울  10.7                     2.7
#
#    wd wdQcflg  hm hmQcflg   pv   td      pa paQcflg      ps psQcflg   ss  \
# 0  50          77          6.6  1.0  1018.5          1029.2
# 1  70          76          6.5  0.8  1019.1          1029.8          0.4
# 2  50          70          6.8  1.4  1019.7          1030.4          1.0
# 3  50          60          6.6  1.1  1020.2          1030.8          1.0
# 4  70          49          6.3  0.4  1020.2          1030.7          1.0
#
#   ssQcflg  icsr dsnw hr3Fhsc dc10Tca dc10LmcsCa clfmAbbrCd lcsCh    vs  \
# ...

# %%
df.drop([], axis=1)
